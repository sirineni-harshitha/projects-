# %%
import tkinter as tk
import mysql.connector 
from tkinter import *
  
def submitact():
     
    user = Username.get()
    passw = password.get()
    data= database.get()

    logintodb(user, passw, data)
  
 
def logintodb(user, passw, data):
     
    # If paswword is enetered by the 
    # user
    if passw:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     password = passw,
                                     db =data)
        cursor = db.cursor()
         
    # If no password is enetered by the
    # user
    else:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     data =data)
        cursor = db.cursor()

def save_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SELECT * from housedata")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='price',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='bedrooms',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='sqft_living',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='floors',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='condition',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
            e=Label(root,width=10,text='yr_built',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)
            e=Label(root,width=10,text='yr_renovated',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=7)   
        i=i+1
    db.close()

def dropping():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("ALTER TABLE housedata DROP COLUMN bedrooms") 
def afterdrop():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT * from housedata")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='price',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='sqft_living',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='floors',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='condition',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='yr_built',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
            e=Label(root,width=10,text='yr_renovated',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)
        
        i=i+1
def cond_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SELECT eid,price,floors from housedata where floors>1")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='price',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='floors',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)     
        i=i+1

def save_query1():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT * from extent")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='zipcode',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='lat',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='long',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='sqft_living15',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='sqft_lot15',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)  
        i=i+1
def cond_query1():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT eid, zipcode from extent where sqft_living15>2140")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='eid',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='zipcode',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
   
        i=i+1 
def cond_query3():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT * from housedata group by floors")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='price',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='sqft_living',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='floors',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='condition',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='yr_built',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5) 
            e=Label(root,width=10,text='yr_renovated',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)  
            
        i=i+1 
        
def input_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute(savequery1.get())
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1  
def inner_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT * from housedata inner join extent on housedata.eid=extent.eid")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1 

root = tk.Tk()
root.geometry("1100x1000")
root.configure(bg='gray')
root.title("DBMS Login Page") 

# Definging the first row
welcome = tk.Label(root, text ="Welcome to HARSHITHA Database GUI", fg = "yellow", bg = "grey",font = "Helvetica 24 bold italic")
welcome.place(x = 350, y = 20)

lblfrstrow = tk.Label(root, text ="Username:", bg='gray',font = "Helvetica 12 bold italic")
lblfrstrow.place(x = 50, y = 50)
 
Username = tk.Entry(root, width = 35)
Username.place(x = 150, y = 50, width = 100)
  
lblsecrow = tk.Label(root, text ="Password:", bg='gray',font = "Helvetica 12 bold italic")
lblsecrow.place(x = 50, y = 80)
 
password = tk.Entry(root, width = 35)
password.place(x = 150, y = 80, width = 100)

lblthrdrow = tk.Label(root, text ="Database:", bg='gray', font = "Helvetica 12 bold italic")
lblthrdrow.place(x = 50, y = 110)
 
database = tk.Entry(root, width = 35)
database.place(x = 150, y = 110, width = 100)
 
submitbtn = tk.Button(root, text ="Login", font = "Helvetica 12 bold italic",
                      bg ='pink', command = submitact)
submitbtn.place(x = 100, y = 150, width = 155)


save = tk.Button(root, text ="all the records from house data", font = "Helvetica 12 bold italic",
                      bg ='pink', command = save_query)
save.place(x = 150, y = 300, width = 455)
cond3 = tk.Button(root, text ="dropping a column", font = "Helvetica 12 bold italic",
                      bg ='pink', command = dropping)
cond3.place(x = 150, y = 350, width = 455)
drop = tk.Button(root, text ="after dropping the column", font = "Helvetica 12 bold italic",
                      bg ='pink', command = afterdrop)
drop.place(x = 150, y = 400, width = 455)
cond1 = tk.Button(root, text ="displaying records where floors >1", font = "Helvetica 12 bold italic",
                      bg ='pink', command = cond_query)
cond1.place(x = 150, y = 450, width = 455)
save1 = tk.Button(root, text ="all the records from extension data", font = "Helvetica 12 bold italic",
                      bg ='pink', command = save_query1)
save1.place(x = 150, y = 500, width = 455)
cond2= tk.Button(root, text ="displaying records where sqft_living15>2140", font = "Helvetica 12 bold italic",
                      bg ='pink', command = cond_query1)
cond2.place(x = 150, y = 550, width = 455)
cond5= tk.Button(root, text ="input", font = "Helvetica 12 bold italic",
                      bg ='pink', command = input_query)
cond5.place(x = 150, y = 800, width = 455)
inner= tk.Button(root, text ="inner joint", font = "Helvetica 12 bold italic",
                      bg ='pink', command = inner_query)
inner.place(x = 150, y = 600, width = 455)

group= tk.Button(root, text ="groupby", font = "Helvetica 12 bold italic",
                      bg ='pink', command = cond_query3)
group.place(x = 150, y = 650, width = 455)

welcome1 = tk.Label(root, text ="User-defined queries:", fg = "yellow", bg = "gray",font = "Helvetica 16 bold italic")
welcome1.place(x = 50, y = 700)

query = tk.Label(root, text ="enter the query:", bg='gray',font = "Helvetica 14 bold italic"  )
query.place(x = 150, y = 750)
 
savequery1 = tk.Entry(root, width = 35)
savequery1.place(x = 300, y = 750, width = 700)

root.mainloop()
